# %%
#Exercises: Level 1

it_companies = {'Facebook', 'Google', 'Microsoft', 'Apple', 'IBM', 'Oracle', 'Amazon'}
print(it_companies)

#1. Find the length of the set it_companies
print('The length of the set "it_companies" is:', len(it_companies))

#2. Add 'Twitter' to it_companies
it_companies.add('Twitter')

#3. Insert multiple IT companies at once to the set it_companies
it_companies.update('Flutterwave','Paxful','Tiktok')

#4. Remove one of the companies from the set it_companies
it_companies.remove('Apple')

#5. What is the difference between remove and discard
#(When you try running this code: it_companies.remove('Instagram') 
#Remove method will raise an error because there is no item called "Instagram" in the set
it_companies.discard('Instagram')
#Discard method will never raise an error when it could'nt find the item called "Instagram" in the set

#Exercises: Level 2
A = {19, 22, 24, 20, 25, 26}
B = {19, 22, 20, 25, 26, 24, 28, 27}
print('This is set A;', A)
print('This is set A;', B)

#1. Join A and B
print('This is the union of set A and B:', A.union(B))

#2. Find A intersection B
print('This is the intersection of set A and B:', A.intersection(B))

#3. Is A subset of B
print('A is a subset of B:', A.issubset(B))

#4. Are A and B disjoint sets
print('A and B are disjoint sets:', A.isdisjoint(B))

#5. Join A with B and B with A
print('joining set A with set B:', A.union(B))
print('Joining set B with set A:', B.union(A))

#6. What is the symmetric difference between A and B
print('The symmetric difference of set A and set B is:', A.symmetric_difference(B))

#7. Delete the sets completely
del A, B

#Exercises: Level 3
#1. Convert the ages to a set and compare the length of the list and the set, which one is bigger?
age = [22, 19, 24, 25, 26, 24, 25, 24]
age_set = set(age)
print('The length of list "age" is bigger than the length of set "age_set":', len(age) == len(age_set))

#2. Explain the difference between the following data types: string, list, tuple and set
print('While string and set store ordered collection of data, list and tuple store an ordered collection of data.')
print('Like string, set and list are mutable except that  a set does not store duplicate data, and tuple is immutable')
print('String is declared in double single quoatation only, list in square brackets, tuple with parenthesis, and set in curly brackets')

#3.  am a teacher and I love to inspire and teach people. How many unique words have been used in the sentence? 
# Use the split methods and set to get the unique words.

sentence = ('am a teacher and I love to inspire and teach people')
print(sentence.upper())
sentence.split()
set_sentence = set(sentence.split())
print('The number of unique words in the sentence is:', len(set_sentence))
