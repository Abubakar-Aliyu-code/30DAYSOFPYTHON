# %%
#Exercises: Level 1
#1. Create an empty tuple
empty_tuple = ()

#2. Create a tuple containing names of your sisters and your brothers (imaginary siblings are fine)
sisters = ('aziza', 'aisha','ummi')
brothers = ('abbati', 'sadiq', 'al-amin', 'khalifa', 'ibrahim')

#3. Join brothers and sisters tuples and assign it to siblings
siblings = sisters + brothers


#4. How many siblings do you have?
print(len(siblings))

#5. Modify the siblings tuple and add the name of your father and mother and assign it to family_members
family_members = list(siblings)
family_members.append('aliyu')
family_members.append('nafisa')
print(family_members)

#Exercises: Level 2
#1. Unpack siblings and parents from family_members
siblings = family_members[0:8]
print(siblings)
parents = family_members[8:10]
print(parents)

#2. Create fruits, vegetables and animal products tuples. 
# Join the three tuples and assign it to a variable called food_stuff_tp.
friuts = ('watermelon','apple','orange')
vegetables = ('bitter leaf', 'lettuce', 'cabbage')
animal_products = ('beef','milk','chicken')

food_stuff_tp = friuts + vegetables + animal_products
print(food_stuff_tp)

#3. Change the about food_stuff_tp tuple to a food_stuff_lt list
food_stuff_tp = list(food_stuff_tp)
print(food_stuff_tp)

#4. Slice out the middle item or items from the food_stuff_tp tuple or food_stuff_lt list.
middle_item = food_stuff_tp[4]
print('The middle item from the food_stuff_tp list:', middle_item)

#5. Slice out the first three items and the last three items from food_staff_lt list
first_three_items = food_stuff_tp[0:3]
print('The first three items from the food_stuff_tp list:', first_three_items)
last_three_items = food_stuff_tp[-3:]
print('The last three items from the food_stuff_tp list:', last_three_items)

#6. Delete the food_staff_tp tuple completely
del food_stuff_tp

#7. Check if an item exists in tuple:
    #Check if an item exists in tuple:
nordic_countries = ('Denmark', 'Finland','Iceland', 'Norway', 'Sweden')
    #Check if 'Estonia' is a nordic country
print('Estonia is a nordic country:','Estonia'  in nordic_countries)
    #Check if 'Iceland' is a nordic country
print('Iceland is a nordic country:','Iceland'  in nordic_countries)
