# %%
# Declare your age as integer variable
age =  int(27)
print(age)
# Declare your height as a float variable
height = float(1.69)
print(height)
# Declare a variable that store a complex number
complex_num = 1+5j
print(complex_num)
# Write a script that prompts the user to enter base and height of the triangle
# and calculate an area of this triangle (area = 0.5 x b x h).
tri_base = float(input('Enter the value of the triangle\'s base'))
tri_height = float(input('Enter the value of the triangle\'s height'))
area = 0.5 * tri_base * tri_height
print('The area of the triangle is; ', area)
# Write a script that prompts the user to enter side a, side b, and side c of the triangle. 
# Calculate the perimeter of the triangle (perimeter = a + b + c).
side_a = float(input('Enter the value of side a of the triangle;'))
side_b = float(input('Enter the value of side b of the triangle;'))
side_c = float(input('Enter the value of side c of the triangle;'))
tri_perimeter = side_a + side_b + side_c
print('The perimeter of the triangle is;', tri_perimeter)

#Get length and width of a rectangle using prompt. 
#Calculate its area (area = length x width) and perimeter (perimeter = 2 x (length + width))
rec_length = float(input('Enter the length of the rectangle;'))
rec_width = float(input('Enter the width of the rectangle;'))
rec_area = rec_length * rec_width
print('The value of the rectangle is; ', rec_area) 
#Get radius of a circle using prompt. 
#Calculate the area (area = pi x r x r) and circumference (c = 2 x pi x r) where pi = 3.14.
circle_rad = float(input('Enter te radius of the circle; '))
circle_area = 3.14 * (circle_rad)**2
print('The area of the circle is; ', circle_area)

# Ex. 8 calculate the slope, x-intercept and y-intercept of y = 2x -2
# y = mx + c 
c = -2
print('The value of the slope is;', c)
# Solving for the x-intercept
y = 0
x = y + 2/2
print("The value of the x-intercept is; ", (x,y))
# Solving for the y-intercept
x = 0
y = 2*(x) - 2
print(" The value of the y-intercept of is;", (x,y))

# Ex. 9 Slope is (m = y2-y1/x2-x1). Find the slope and Euclidean distance between point (2, 2) and point (6,10)
x1, x2, y1, y2 = 2, 6, 2, 10
#Solving for the slope (m)
m = y2 - y1/x2 - x1
print('The value of the slope(m) is; ', m)
#For Euclidean distance(E_dist)
E_dist = ((x2 - x1) + (y2 - y1))**1/2
print('The value of the Euclidean distance is;', E_dist)

# Ex. 10 Compare the slopes in tasks 8 and 9
print('The value of slope(c) and slope(m) are eqaul;', c== m)

#Ex. 11 Calculate the value of y (y = x^2 + 6x + 9). 
# Try to use different x values and figure out at what x value y is going to be 0.

x_values = set ([-10, -9, -8, -7, -6, -5, -4, -3, -2, 0, 2, 3, 4, 5, 6, 7, 8, 9, 10])
for x in x_values:
    y = x**2 + 6*x + 9
    if y == 0:
        print('Testing values of x ranging from -10 to 10 on the given equation: y = x^2 + 6x + 9, y would equal to zero only when the value of x is equal to', x)

#Ex. 12 Find the length of 'python' and 'dragon' and make a falsy comparison statement.
p = 'python'
d = 'dragon'
print('The length of python is not equivalent to the length of dragon: ', len(p) != len(d))

#Ex. 13 Use and operator to check if 'on' is found in both 'python' and 'dragon'

p = 'python'
d = 'dragon'
print('"ON" is found is both python and dragon:', 'on' in p and 'o' not in d)

# Ex. 14 I HOPE THIS COURSE IS NOT FULL OF JARGON. Use in operator to check if jargon is in the sentence.
s = 'I hope this course is not full of jargon.'
print('"JARGON" is in the sentence:', 'jargon' in s)

#Ex. 15 There is no 'on' in both dragon and python
p = 'python'
d = 'dragon'
print('There is no "ON" in both dragon and python:', 'on' not in p and 'on' not in d)

#Ex. 16 Find the length of the text python and convert the value to float and convert it to string
p = 'python'
print('The length of the word "python" in float and string form are:', 
float(len(p)), 'and', str(len(p)), 'respectively.')

#Ex. 17 Even numbers are divisible by 2 and the remainder is zero.
# How do you check if a number is even or not using python?
number = int(input("Put any number here to know if it is even or odd:"))

if number % 2 == 0:
    print('The number is even.')
else:
    print('The number is odd.')

#Ex. 18 Check if the floor division of 7 by 3 is equal to the int converted value of 2.7.
x = 7
y = 3
v= 2.7
floor_div = 7//3

print('The floor division of 7 by 3 is', floor_div, 'and the value is equal to the int converted value of 2.7:'
,int(v) == floor_div)

#Ex. 19 Check if type of '10' is equal to type of 10
A = 10
B = '10'

print('The type of "10" is equal to type of "10":', type(A) == type(B))

# Ex. 20 Check if int('9.8') is equal to 10
a = 10
b = int (9.8)
print('10 is equal to int(9.8):', a == b)

#Ex. 21 Write a script that prompts the user to enter hours and rate per hour. Calculate pay of the person?
hour = float(input("Enter the hours:"))
rate = float(input("Enter the rate per hour:"))
print('Your total payment is', hour*rate)

#Ex. 22 Write a script that prompts the user to enter number of years. 
#Calculate the number of seconds a person can live. Assume a person can live hundred years
year = int(input('Enter the number of years:'))
num_sec = year * 31536000
print('In', year, 'years, you are going to live for', num_sec)

#Ex. 23 Write a Python script that displays the following table
