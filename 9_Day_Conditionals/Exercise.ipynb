# %%
#Exercises: Level 1
#1. Get user input using input(“Enter your age: ”). If user is 18 or older, give feedback:
#  You are old enough to drive. If below 18 give feedback to wait for the missing amount of years. 
user_input = int(input('Enter your age:'))
if user_input >= 18:
    print('You are old enough to drive!')
else:
    print('Oops! You need', 18-user_input, 'more year(s) to be eligible to drive!')

#Ex. 2 Compare the values of my_age and your_age using if … else. 
# Who is older (me or you)? Use input(“Enter your age: ”) to get the age as input. 
# You can use a nested condition to print 'year' for 1 year difference in age, 'years' for bigger differences, and a custom text if my_age = your_age.

your_age = int(input('Enter your age:'))
if your_age == 26:
    print('Your are my age mate!')
elif your_age < 26:
    print('You are', 26-your_age, 'year(s) younger than me!')
elif your_age > 26:
      print('You are', your_age-26, 'year(s) older than me!' )

#Ex. 3 Get two numbers from the user using input prompt. 
# If a is greater than b return a is greater than b, if a is less b return a is smaller than b, else a is equal to b.

first_num = int(input('Enter your first number:'))
second_num = int(input('Enter your second number:'))
if first_num > second_num:
    print(first_num, 'is greater than',second_num)
elif first_num < second_num:
    print(first_num, 'is lesser than',second_num)
else:
     print(first_num, 'is equal to',second_num)

#Exercises: Level 2
#Ex. 1 Write a code which gives grade to students according to theirs scores:
user_grade =float(input('Put in your score here:'))
if user_grade >= 90:
    print('You got an A grade!')
elif user_grade <= 49:
    print('Your grade is F!')
elif user_grade >= 70 and user_grade <= 89:
    print('You got a B grade!')
elif user_grade >= 50 and user_grade <= 59:
    print('You got a D grade!')
elif user_grade >=60 and user_grade <= 69:
    print('You got a C grade!')


#Ex. 2 Check if the season is Autumn, Winter, Spring or Summer. If the user input is: September, October or November, the season is Autumn. 
# December, January or February, the season is Winter. March, April or May, the season is Spring June, July or August, the season is Summer
season_input = str(input('Enter the name of a month:'))
if season_input == 'september'or  season_input == 'october'or season_input == 'november':
    print('The season is Autum.')
elif season_input == 'december' or season_input == 'january' or season_input == 'february':
    print('The season is Winter.')
elif season_input == 'march' or  season_input == 'april' or season_input == 'may':
    print('The season is Spring.')
elif season_input == 'june' or  season_input == 'july' or season_input == 'august':
    print('The season is Summer.')

#Ex. 3 The following list contains some fruits:

fruits = ['banana', 'orange', 'mango', 'lemon']

#If a fruit doesn't exist in the list add the fruit to the list and print the modified list. 
# If the fruit exists print('That fruit already exist in the list')

fruit_input = str(input('Enter the name of the fruit:'))
if fruit_input not in fruits:
    fruits.append(fruit_input)
    print(fruit_input, 'successfully added to the list:', fruits)
elif fruit_input in fruits:
    print(fruit_input, 'already exist in the list!')

#Exercises: Level 3
#Here we have a person dictionary. Feel free to modify it!

person={
    'first_name': 'Asabeneh',
    'last_name': 'Yetayeh',
    'age': 250,
    'country': 'Finland',
    'is_marred': True,
    'skills': ['JavaScript', 'React', 'Node', 'MongoDB', 'Python'],
    'address': {
        'street': 'Space street',
        'zipcode': '02210'
    }
    }

#1. Check if the person dictionary has skills key, if so print out the middle skill in the skills list.
if 'skills' in person.keys():
    print('The middle skill in the skills key is:Node')

#2. Check if the person dictionary has skills key, if so check if the person has 'Python' skill and print out the result.
if 'Python' in person['skills']:
    print('The person has python skill')

#3. If a person skills has only JavaScript and React, print('He is a front end developer'), 
# if the person skills has Node, Python, MongoDB, print('He is a backend developer'), 
# if the person skills has React, Node and MongoDB, Print('He is a fullstack developer'), else print('unknown title')
#  - for more accurate results more conditions can be nested!
if
